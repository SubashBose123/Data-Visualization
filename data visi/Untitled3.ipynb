# %%
import pandas as pd
data_csv=pd.read_csv("project tasks_data_mito.csv")

# %%
data_csv.head(2)
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#    quantity  discount   profit  year
# 0         2       0.0  106.140  2011
# 1         3       0.1   36.036  2011

# %%
data=pd.read_excel(r"C:\Users\SUBASH\Downloads\project-tasks_data_mito.xlsx")

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year
# ...

# %%
data.shape
# Out:
# (51290, 14)

# %%
data['nwe']=data['quantity']*10
data.head(1)
# Out:
#        order_id  order_date    customer_name   segment  country  region  \
# 0  AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer  Algeria  Africa
#
#          product_id         category         product_name sales  quantity  \
# 0  OFF-TEN-10000025  Office Supplies  Tenex Lockers, Blue   408         2
#
#    discount  profit  year  nwe
# 0       0.0  106.14  2011   20

# %%
data.insert(2,'second_clmn',data.discount+1)

# %%
data.head(1)
# Out:
#        order_id  order_date  second_clmn    customer_name   segment  country  \
# 0  AG-2011-2040  01-01-2011          1.0  Toby Braunhardt  Consumer  Algeria
#
#    region        product_id         category         product_name sales  \
# 0  Africa  OFF-TEN-10000025  Office Supplies  Tenex Lockers, Blue   408
#
#    quantity  discount  profit  year  nwe
# 0         2       0.0  106.14  2011   20

# %%
data.drop('second_clmn',axis=1)
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
data.drop('second_clmn',axis=1,inplace=True)

# %%
data.head(1)
# Out:
#        order_id  order_date    customer_name   segment  country  region  \
# 0  AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer  Algeria  Africa
#
#          product_id         category         product_name sales  quantity  \
# 0  OFF-TEN-10000025  Office Supplies  Tenex Lockers, Blue   408         2
#
#    discount  profit  year  nwe
# 0       0.0  106.14  2011   20

# %%
data.pivot_table(index='region',columns='segment',values='discount')
# Out:
# segment         Consumer  Corporate  Home Office
# region
# Africa          0.155733   0.163948     0.148658
# Canada          0.000000   0.000000     0.000000
# Caribbean       0.134435   0.128746     0.148828
# Central         0.141548   0.134564     0.138178
# Central Asia    0.060749   0.077651     0.069466
# EMEA            0.196690   0.195934     0.194656
# East            0.147447   0.144356     0.141036
# North           0.099059   0.097243     0.085002
# North Asia      0.050000   0.037994     0.061957
# Oceania         0.157975   0.147768     0.147906
# South           0.149212   0.151928     0.143644
# Southeast Asia  0.264461   0.280935     0.280000
# West            0.107506   0.113958     0.106918

# %%
data.pivot_table(index='region',columns='segment',values='discount',aggfunc={"discount":'sum'})
# Out:
# segment         Consumer  Corporate  Home Office
# region
# Africa           370.800    215.100      132.900
# Canada             0.000      0.000        0.000
# Caribbean        111.312     65.274       52.834
# Central          818.432    446.888      278.290
# Central Asia      63.300     47.600       27.300
# EMEA             499.200    308.400      178.500
# East             216.600    126.600       70.800
# North            244.478    144.600       70.552
# North Asia        58.500     26.900       28.500
# Oceania          290.200    155.600       88.300
# South            519.110    303.552      167.776
# Southeast Asia   436.360    255.370      159.600
# West             179.750    109.400       61.050

# %%
import matplotlib.pyplot as plt
plt.scatter(data.quantity,data['discount'])

# %%
plt.scatter(data.quantity,data.discount)
plt.show()

# %%
plt.scatter(data.quantity,data.discount,label='mychat')
plt.legend()
plt.show()

# %%
plt.scatter(data.quantity,data.discount,label='mychat')
plt.legend()
plt.xlabel('quantity')
plt.ylabel('discount')
plt.show()

# %%
data['sss']=data['quantity']+data['discount']

# %%
data
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...
